# %%
#8.finding cumulative average using accumulate and lambda functions
z= [9,8,7,6,5]
import itertools as it
f=[]
f = it.accumulate(list(enumerate(z)), lambda p,q: (q[0], (p[1]*(p[0]+1) + q[1])/(q[0]+1)))
print(list(map(lambda p: p[1], f)))
# Out:
# [9, 8.5, 8.0, 7.5, 7.0]
