# %%
#9.converting words into uppercase using lambda and map  functions
isbool=['True','FALse','tRUe','tRue','False','faLse']
lis=[a.upper() for a in isbool]
print(lis)
# Out:
# ['TRUE', 'FALSE', 'TRUE', 'TRUE', 'FALSE', 'FALSE']
